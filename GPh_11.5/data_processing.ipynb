# %%
import numpy as np
from scipy.optimize import curve_fit
from matplotlib import pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('data.csv')
I = data['I, mA']
U = data['U, V']

data
# Out:
#      I, mA    U, V
# 0   0.0190  0.0000
# 1   0.0360  0.0030
# 2   0.3930  0.0021
# 3   0.5720  0.0031
# 4   0.7580  0.0041
# 5   0.9480  0.0051
# 6   1.0520  0.0057
# 7   1.1800  0.0064
# 8   1.3000  0.0071
# 9   1.3990  0.0077
# 10  1.5480  0.0086
# 11  1.7100  0.0096
# 12  1.8620  0.0105
# 13  1.9290  0.0110
# 14  2.0530  0.0118
# 15  2.1600  0.0125
# 16  2.2770  0.0134
# 17  2.4480  0.0146
# 18  2.5750  0.0156
# 19  2.7090  0.0166
# 20  2.8490  0.0177
# 21  2.9700  0.0187
# 22  3.0890  0.0198
# 23  3.2060  0.0209
# 24  3.3120  0.0219
# 25  3.4360  0.0231
# 26  3.5220  0.0240
# 27  3.6180  0.0251
# 28  3.7470  0.0265
# 29  3.8620  0.0279
# 30  4.0210  0.0300
# 31  4.1780  0.0324
# 32  2.1260  0.2170
# 33  0.6150  0.3760
# 34  0.6710  0.3828
# 35  0.7740  0.3920
# 36  0.9500  0.4030
# 37  1.1360  0.4112
# 38  1.5210  0.4232
# 39  1.9340  0.4321
# 40  2.5110  0.4411
# 41  4.9400  0.4627
# 42  6.0293  0.4689
# 43  4.1790  0.4573
# 44  2.0510  0.2131
# 45  2.2970  0.2234
# ...

# %%
Y = I
X = U


# график
fig, ax = plt.subplots(figsize=(10, 6))
dots = X
ax.scatter(X, Y, s = 5)
lgnd = ax.legend(['Data'], loc='best', shadow=True)

# ax.set_title(r'')
ax.set_ylabel(r'$I, \; mA$')
ax.set_xlabel(r'$U, \; V$')


ax.minorticks_on()
ax.grid(which='minor', color = 'gray', linestyle = ':', linewidth = 0.5)
ax.grid(which='major', linewidth = 0.5)

# plt.errorbar(X, Y, fmt = 'ro', markersize = '2', yerr = S_e, capsize = 1, elinewidth = 1, capthick = 1, ecolor = 'dimgray')

plt.savefig('pictures/graph1.png', dpi=400, quality=100)
plt.show()
# Out:
# <ipython-input-4-873fb78aeb8d>:22: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "quality" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig('pictures/graph1.png', dpi=400, quality=100)

# %%
I = lambda x: x*(r1 + 2*(r2+r3))/((r1+2*r2)*r3)
r1 = 680
r2 = 100
r3 = 120
np.vectorize(I)([0.01,0.31,0.44])
# Out:
# array([0.00010606, 0.00328788, 0.00466667])

# %%
data.sort_values(by = 'U, V')
# Out:
#      I, mA    U, V
# 0   0.0190  0.0000
# 2   0.3930  0.0021
# 1   0.0360  0.0030
# 3   0.5720  0.0031
# 4   0.7580  0.0041
# 5   0.9480  0.0051
# 6   1.0520  0.0057
# 7   1.1800  0.0064
# 8   1.3000  0.0071
# 9   1.3990  0.0077
# 10  1.5480  0.0086
# 11  1.7100  0.0096
# 12  1.8620  0.0105
# 13  1.9290  0.0110
# 14  2.0530  0.0118
# 15  2.1600  0.0125
# 16  2.2770  0.0134
# 17  2.4480  0.0146
# 18  2.5750  0.0156
# 19  2.7090  0.0166
# 20  2.8490  0.0177
# 21  2.9700  0.0187
# 22  3.0890  0.0198
# 23  3.2060  0.0209
# 24  3.3120  0.0219
# 25  3.4360  0.0231
# 26  3.5220  0.0240
# 27  3.6180  0.0251
# 46  3.7100  0.0261
# 28  3.7470  0.0265
# 29  3.8620  0.0279
# 30  4.0210  0.0300
# 31  4.1780  0.0324
# 44  2.0510  0.2131
# 32  2.1260  0.2170
# 45  2.2970  0.2234
# 33  0.6150  0.3760
# 34  0.6710  0.3828
# 35  0.7740  0.3920
# 36  0.9500  0.4030
# 37  1.1360  0.4112
# 38  1.5210  0.4232
# 39  1.9340  0.4321
# 40  2.5110  0.4411
# 43  4.1790  0.4573
# 41  4.9400  0.4627
# ...
